# %%
import pandas as pd
data=[10,2,32.3,23,49]
series=pd.Series(data)
print(series)
print(series.dtype)
# Out:
# 0    10.0
# 1     2.0
# 2    32.3
# 3    23.0
# 4    49.0
# dtype: float64
# float64

# %%
import numpy as np
array=np.array([[10,5,20],[14,25,6],[7,18,29]])
print(array)
df=pd.DataFrame(array)
print(df)
# Out:
# [[10  5 20]
#  [14 25  6]
#  [ 7 18 29]]
#     0   1   2
# 0  10   5  20
# 1  14  25   6
# 2   7  18  29

# %%
data={'a':10,'b':20,'c':30,'d':5}
series=pd.Series(data)
print(series)
# Out:
# a    10
# b    20
# c    30
# d     5
# dtype: int64

# %%
data={'a':10,'b':20,'c':30,'d':5}
series=pd.Series(data)
print(series)
# Out:
# a    10
# b    20
# c    30
# d     5
# dtype: int64

# %%
data=np.array([10,20,30,40,50,60])
i=['a','b','c','d','e','f']
series=pd.Series(data,index=i)
print(series)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int32

# %%
import numpy as np
array=np.array([[10,5,20],[14,25,6],[7,18,29]])
print(array)
df=pd.DataFrame(array)
print(df)
# Out:
# [[10  5 20]
#  [14 25  6]
#  [ 7 18 29]]
#     0   1   2
# 0  10   5  20
# 1  14  25   6
# 2   7  18  29

# %%
data=[10,2,32.3,23,49]
i=['a','b','c','d','e']
series=pd.Series(data,index=i)
print(series)
series.replace(10,43)
print(series)
# Out:
# a    10.0
# b     2.0
# c    32.3
# d    23.0
# e    49.0
# dtype: float64
# a    10.0
# b     2.0
# c    32.3
# d    23.0
# e    49.0
# dtype: float64

# %%
import pandas as pd
data={'Name':['Alice','Bob','MRU','jOHN'],\
      'Age':[24,52,23,67],\
      'Country':["USA","UK","AUS","India"]}
i=['a','b','c','d']
df=pd.DataFrame(data,index=i)
print(df)
# Out:
#     Name  Age Country
# a  Alice   24     USA
# b    Bob   52      UK
# c    MRU   23     AUS
# d   jOHN   67   India

# %%
import numpy as np
array=np.array([[100,350,3.5],[90,450,4.5],[80,550,5.5],[70,650,6.5],[67,950,9.5],[89,359,3.59],[50,850,8.50],[30,990,9.90]])
i=['Sem1','Sem2','Sem3','Sem4','Sem5','Sem6','Sem7','Sem8']
df=pd.DataFrame(array,index=i,columns=["Attendance","Marks","CGPA"])
print(df)
# Out:
#       Attendance  Marks  CGPA
# Sem1       100.0  350.0  3.50
# Sem2        90.0  450.0  4.50
# Sem3        80.0  550.0  5.50
# Sem4        70.0  650.0  6.50
# Sem5        67.0  950.0  9.50
# Sem6        89.0  359.0  3.59
# Sem7        50.0  850.0  8.50
# Sem8        30.0  990.0  9.90

# %%
iris_df=pd.read_csv("iris.csv")
print(iris_df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_df.head(24)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
iris_df.tail(27)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 123           6.3          2.7           4.9          1.8  Virginica
# 124           6.7          3.3           5.7          2.1  Virginica
# 125           7.2          3.2           6.0          1.8  Virginica
# 126           6.2          2.8           4.8          1.8  Virginica
# 127           6.1          3.0           4.9          1.8  Virginica
# 128           6.4          2.8           5.6          2.1  Virginica
# 129           7.2          3.0           5.8          1.6  Virginica
# 130           7.4          2.8           6.1          1.9  Virginica
# 131           7.9          3.8           6.4          2.0  Virginica
# 132           6.4          2.8           5.6          2.2  Virginica
# 133           6.3          2.8           5.1          1.5  Virginica
# 134           6.1          2.6           5.6          1.4  Virginica
# 135           7.7          3.0           6.1          2.3  Virginica
# ...

# %%
iris_df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris_df.shape)
print(iris_df.ndim)
print(iris_df.size)
# Out:
# (150, 5)
# 2
# 750

# %%
iris_df[["sepal.length","petal.width"]]
# Out:
#      sepal.length  petal.width
# 0             5.1          0.2
# 1             4.9          0.2
# 2             4.7          0.2
# 3             4.6          0.2
# 4             5.0          0.2
# ..            ...          ...
# 145           6.7          2.3
# 146           6.3          1.9
# 147           6.5          2.0
# 148           6.2          2.3
# 149           5.9          1.8
#
# [150 rows x 2 columns]

# %%
iris_df.iloc[10:24,:]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa
# 21           5.1          3.7           1.5          0.4  Setosa
# 22           4.6          3.6           1.0          0.2  Setosa
# ...

# %%
iris_df.iloc[10:24,[0,3]]
# Out:
#     sepal.length  petal.width
# 10           5.4          0.2
# 11           4.8          0.2
# 12           4.8          0.1
# 13           4.3          0.1
# 14           5.8          0.2
# 15           5.7          0.4
# 16           5.4          0.4
# 17           5.1          0.3
# 18           5.7          0.3
# 19           5.1          0.3
# 20           5.4          0.2
# 21           5.1          0.4
# 22           4.6          0.2
# 23           5.1          0.5

# %%
iris_df.loc[10:24,"sepal.length":"petal.length"]
# Out:
#     sepal.length  sepal.width  petal.length
# 10           5.4          3.7           1.5
# 11           4.8          3.4           1.6
# 12           4.8          3.0           1.4
# 13           4.3          3.0           1.1
# 14           5.8          4.0           1.2
# 15           5.7          4.4           1.5
# 16           5.4          3.9           1.3
# 17           5.1          3.5           1.4
# 18           5.7          3.8           1.7
# 19           5.1          3.8           1.5
# 20           5.4          3.4           1.7
# 21           5.1          3.7           1.5
# 22           4.6          3.6           1.0
# 23           5.1          3.3           1.7
# 24           4.8          3.4           1.9

# %%
iris_df.loc[10:20:5,:]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa

# %%
data={"Weight":[66,74,34,98,86,55],\
      "height":[156,176,134,194,168,157]}
bmi=pd.DataFrame(data)
bmi
# Out:
#    Weight  height
# 0      66     156
# 1      74     176
# 2      34     134
# 3      98     194
# 4      86     168
# 5      55     157

# %%
bmi["BMI"]=bmi["Weight"]/(bmi["height"]/100)**2
bmi
# Out:
#    Weight  height        BMI
# 0      66     156  27.120316
# 1      74     176  23.889463
# 2      34     134  18.935175
# 3      98     194  26.038899
# 4      86     168  30.470522
# 5      55     157  22.313278

# %%
bmi.loc[3]=[78,np.nan,np.nan]
bmi
# Out:
#    Weight  height        BMI
# 0      66   156.0  27.120316
# 1      74   176.0  23.889463
# 2      34   134.0  18.935175
# 3      78     NaN        NaN
# 4      86   168.0  30.470522
# 5      55   157.0  22.313278

# %%
bmi.loc[5]=[np.nan,67,np.nan]
bmi
# Out:
#    Weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    74.0   176.0  23.889463
# 2    34.0   134.0  18.935175
# 3    78.0     NaN        NaN
# 4    86.0   168.0  30.470522
# 5     NaN    67.0        NaN

# %%
bmi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  5 non-null      float64
#  1   height  5 non-null      float64
#  2   BMI     4 non-null      float64
# dtypes: float64(3)
# memory usage: 276.0 bytes

# %%
bmi.isnull().sum()
# Out:
# Weight    1
# height    1
# BMI       2
# dtype: int64

# %%
bmi["Weight"]=bmi["Weight"].fillna(65)
bmi
# Out:
#    Weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    74.0   176.0  23.889463
# 2    34.0   134.0  18.935175
# 3    78.0     NaN        NaN
# 4    86.0   168.0  30.470522
# 5    65.0    67.0        NaN

# %%
bmi["height"]=bmi["height"].fillna(165)
bmi
# Out:
#    Weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    74.0   176.0  23.889463
# 2    34.0   134.0  18.935175
# 3    78.0   165.0        NaN
# 4    86.0   168.0  30.470522
# 5    65.0    67.0        NaN

# %%
bmi["BMI_NEW"]=bmi["Weight"]/(bmi["height"]/100)**2
bmi
# Out:
#    Weight  height        BMI     BMI_NEW
# 0    66.0   156.0  27.120316   27.120316
# 1    74.0   176.0  23.889463   23.889463
# 2    34.0   134.0  18.935175   18.935175
# 3    78.0   165.0        NaN   28.650138
# 4    86.0   168.0  30.470522   30.470522
# 5    65.0    67.0        NaN  144.798396

# %%
bmi.drop("BMI",axis=1,inplace=True)
bmi
# Out:
#    Weight  height     BMI_NEW
# 0    66.0   156.0   27.120316
# 1    74.0   176.0   23.889463
# 2    34.0   134.0   18.935175
# 3    78.0   165.0   28.650138
# 4    86.0   168.0   30.470522
# 5    65.0    67.0  144.798396

# %%
import matplotlib.pyplot as plt
plt.hist(iris_df["sepal.length"],color="skyblue")
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)
